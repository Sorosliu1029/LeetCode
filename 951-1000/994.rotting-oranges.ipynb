# %% [markdown]
# ### 994. Rotting Oranges

# %% [markdown]
# <p>You are given an <code>m x n</code> <code>grid</code> where each cell can have one of three values:</p>
#
# <ul>
# 	<li><code>0</code> representing an empty cell,</li>
# 	<li><code>1</code> representing a fresh orange, or</li>
# 	<li><code>2</code> representing a rotten orange.</li>
# </ul>
#
# <p>Every minute, any fresh orange that is <strong>4-directionally adjacent</strong> to a rotten orange becomes rotten.</p>
#
# <p>Return <em>the minimum number of minutes that must elapse until no cell has a fresh orange</em>. If <em>this is impossible, return</em> <code>-1</code>.</p>
#
# <p>&nbsp;</p>
# <p><strong class="example">Example 1:</strong></p>
# <img alt="" src="https://assets.leetcode.com/uploads/2019/02/16/oranges.png" style="width: 650px; height: 137px;" />
# <pre>
# <strong>Input:</strong> grid = [[2,1,1],[1,1,0],[0,1,1]]
# <strong>Output:</strong> 4
# </pre>
#
# <p><strong class="example">Example 2:</strong></p>
#
# <pre>
# <strong>Input:</strong> grid = [[2,1,1],[0,1,1],[1,0,1]]
# <strong>Output:</strong> -1
# <strong>Explanation:</strong> The orange in the bottom left corner (row 2, column 0) is never rotten, because rotting only happens 4-directionally.
# </pre>
#
# <p><strong class="example">Example 3:</strong></p>
#
# <pre>
# <strong>Input:</strong> grid = [[0,2]]
# <strong>Output:</strong> 0
# <strong>Explanation:</strong> Since there are already no fresh oranges at minute 0, the answer is just 0.
# </pre>
#
# <p>&nbsp;</p>
# <p><strong>Constraints:</strong></p>
#
# <ul>
# 	<li><code>m == grid.length</code></li>
# 	<li><code>n == grid[i].length</code></li>
# 	<li><code>1 &lt;= m, n &lt;= 10</code></li>
# 	<li><code>grid[i][j]</code> is <code>0</code>, <code>1</code>, or <code>2</code>.</li>
# </ul>

# %% [markdown]
# #### Difficulty: Medium, AC rate: 57.7%
#
# #### Topics:
# Array | Breadth-First Search | Matrix
#
# #### Links:
#  🎁 [Question Detail](https://leetcode.com/problems/rotting-oranges/description/) | 🎉 [Question Solution](https://leetcode.com/problems/rotting-oranges/solution/) | 💬 [Question Discussion](https://leetcode.com/problems/rotting-oranges/discuss/?orderBy=most_votes)

# %% [markdown]
# #### Test Case(s):
#
# 1. `[[2,1,1],[1,1,0],[0,1,1]]`
# 2. `[[2,1,1],[0,1,1],[1,0,1]]`
# 3. `[[0,2]]`

# %% [markdown]
# ---
# What's your idea?
#
# cuz there could be multiple 2s, so there will be multiple lines of frontier, then each frontier, bfs
#
# ---

# %%
from typing import List

# %%
class Solution:
    neighbours = [(0,-1),(0,1),(-1,0),(1,0)]
    
    def orangesRotting(self, grid: List[List[int]]) -> int:
        lines_of_frontier = []
        m, n = len(grid), len(grid[0])
        
        for i in range(m):
            for j in range(n):
                if grid[i][j] == 2:
                    lines_of_frontier.append([(i,j)])
        elapses = [0] * len(lines_of_frontier)

        while any(filter(None, lines_of_frontier)):
            for k, frontier in enumerate(lines_of_frontier):
                new_frontier = []
                for i, j in frontier:
                    for di,dj in self.neighbours:
                        ni, nj = i+di, j+dj
                        if 0<=ni<m and 0<=nj<n and grid[ni][nj] == 1:
                            new_frontier.append((ni,nj))
                            grid[ni][nj] = 0

                lines_of_frontier[k] = new_frontier
                if new_frontier:
                    elapses[k] += 1

        for i in range(m):
            for j in range(n):
                if grid[i][j] == 1:
                    return -1
        return max(elapses, default=0)

# %%
s = Solution()
s.orangesRotting([[2,1,1],[1,1,0],[0,1,1]])
# Out:
# 4

# %%
s.orangesRotting([[2,1,1],[0,1,1],[1,0,1]])
# Out:
# -1

# %%
s.orangesRotting([[0,2]])
# Out:
# 0

# %%
s.orangesRotting([[0]])
# Out:
# 0

# %% [markdown]
# 😃 Result: Accepted
# 💯 Passed Test Case: 307 / 307
# 🚀 Runtime: 4 ms, Memory: 17.9 MB
# 🉑 Runtime Percentile: better than 46.41%, Memory Percentile: better than 43.81%
# 📆 Finished At: Sat, 29 Nov 2025 20:43:58 GMT

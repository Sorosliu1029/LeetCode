# %% [markdown]
# ### 1143. Longest Common Subsequence

# %% [markdown]
# <p>Given two strings <code>text1</code> and <code>text2</code>, return <em>the length of their longest <strong>common subsequence</strong>. </em>If there is no <strong>common subsequence</strong>, return <code>0</code>.</p>
#
# <p>A <strong>subsequence</strong> of a string is a new string generated from the original string with some characters (can be none) deleted without changing the relative order of the remaining characters.</p>
#
# <ul>
# 	<li>For example, <code>&quot;ace&quot;</code> is a subsequence of <code>&quot;abcde&quot;</code>.</li>
# </ul>
#
# <p>A <strong>common subsequence</strong> of two strings is a subsequence that is common to both strings.</p>
#
# <p>&nbsp;</p>
# <p><strong class="example">Example 1:</strong></p>
#
# <pre>
# <strong>Input:</strong> text1 = &quot;abcde&quot;, text2 = &quot;ace&quot;
# <strong>Output:</strong> 3
# <strong>Explanation:</strong> The longest common subsequence is &quot;ace&quot; and its length is 3.
# </pre>
#
# <p><strong class="example">Example 2:</strong></p>
#
# <pre>
# <strong>Input:</strong> text1 = &quot;abc&quot;, text2 = &quot;abc&quot;
# <strong>Output:</strong> 3
# <strong>Explanation:</strong> The longest common subsequence is &quot;abc&quot; and its length is 3.
# </pre>
#
# <p><strong class="example">Example 3:</strong></p>
#
# <pre>
# <strong>Input:</strong> text1 = &quot;abc&quot;, text2 = &quot;def&quot;
# <strong>Output:</strong> 0
# <strong>Explanation:</strong> There is no such common subsequence, so the result is 0.
# </pre>
#
# <p>&nbsp;</p>
# <p><strong>Constraints:</strong></p>
#
# <ul>
# 	<li><code>1 &lt;= text1.length, text2.length &lt;= 1000</code></li>
# 	<li><code>text1</code> and <code>text2</code> consist of only lowercase English characters.</li>
# </ul>

# %% [markdown]
# #### Difficulty: Medium, AC rate: 58.6%
#
# #### Topics:
# String | Dynamic Programming
#
# #### Links:
#  🎁 [Question Detail](https://leetcode.com/problems/longest-common-subsequence/description/) | 🎉 [Question Solution](https://leetcode.com/problems/longest-common-subsequence/solution/) | 💬 [Question Discussion](https://leetcode.com/problems/longest-common-subsequence/discuss/?orderBy=most_votes)
#
# #### Hints:
# <details><summary>Hint 0  🔍</summary>Try dynamic programming.
# DP[i][j] represents the longest common subsequence of text1[0 ... i] & text2[0 ... j].</details>
# <details><summary>Hint 1  🔍</summary>DP[i][j] = DP[i - 1][j - 1] + 1 , if text1[i] == text2[j]
# DP[i][j] = max(DP[i - 1][j], DP[i][j - 1]) , otherwise</details>

# %% [markdown]
# #### Test Case(s):
#
# 1. `"abcde"`
# `"ace"`
# 2. `"abc"`
# `"abc"`
# 3. `"abc"`
# `"def"`

# %% [markdown]
# ---
# What's your idea?
#
# dp, follow hints
#
# ---

# %%
class Solution:
    def longestCommonSubsequence(self, text1: str, text2: str) -> int:
        dp = [[0 for _ in range(len(text2)+1)] for _ in range(len(text1)+1)]
        for i, c1 in enumerate(text1, start=1):
            for j, c2 in enumerate(text2, start=1):
                dp[i][j] = dp[i-1][j-1] + 1 if c1 == c2 else max(dp[i-1][j], dp[i][j-1])
        return dp[len(text1)][len(text2)]

# %%
s = Solution()
s.longestCommonSubsequence("abcde", "ace")
# Out:
# 3

# %%
s.longestCommonSubsequence("abc", "abc")
# Out:
# 3

# %%
s.longestCommonSubsequence("abc", "def")
# Out:
# 0

# %% [markdown]
# 😃 Result: Accepted
# 💯 Passed Test Case: 47 / 47
# 🚀 Runtime: 457 ms, Memory: 43.5 MB
# 🉑 Runtime Percentile: better than 70.37%, Memory Percentile: better than 35.15%
# 📆 Finished At: Fri, 21 Nov 2025 15:45:26 GMT

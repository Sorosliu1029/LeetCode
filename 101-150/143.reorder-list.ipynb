# %% [markdown]
# ### 143. Reorder List

# %% [markdown]
# <p>You are given the head of a singly linked-list. The list can be represented as:</p>
#
# <pre>
# L<sub>0</sub> &rarr; L<sub>1</sub> &rarr; &hellip; &rarr; L<sub>n - 1</sub> &rarr; L<sub>n</sub>
# </pre>
#
# <p><em>Reorder the list to be on the following form:</em></p>
#
# <pre>
# L<sub>0</sub> &rarr; L<sub>n</sub> &rarr; L<sub>1</sub> &rarr; L<sub>n - 1</sub> &rarr; L<sub>2</sub> &rarr; L<sub>n - 2</sub> &rarr; &hellip;
# </pre>
#
# <p>You may not modify the values in the list&#39;s nodes. Only nodes themselves may be changed.</p>
#
# <p>&nbsp;</p>
# <p><strong class="example">Example 1:</strong></p>
# <img alt="" src="https://assets.leetcode.com/uploads/2021/03/04/reorder1linked-list.jpg" style="width: 422px; height: 222px;" />
# <pre>
# <strong>Input:</strong> head = [1,2,3,4]
# <strong>Output:</strong> [1,4,2,3]
# </pre>
#
# <p><strong class="example">Example 2:</strong></p>
# <img alt="" src="https://assets.leetcode.com/uploads/2021/03/09/reorder2-linked-list.jpg" style="width: 542px; height: 222px;" />
# <pre>
# <strong>Input:</strong> head = [1,2,3,4,5]
# <strong>Output:</strong> [1,5,2,4,3]
# </pre>
#
# <p>&nbsp;</p>
# <p><strong>Constraints:</strong></p>
#
# <ul>
# 	<li>The number of nodes in the list is in the range <code>[1, 5 * 10<sup>4</sup>]</code>.</li>
# 	<li><code>1 &lt;= Node.val &lt;= 1000</code></li>
# </ul>

# %% [markdown]
# #### Difficulty: Medium, AC rate: 63.8%
#
# #### Topics:
# Linked List | Two Pointers | Stack | Recursion
#
# #### Links:
#  🎁 [Question Detail](https://leetcode.com/problems/reorder-list/description/) | 🎉 [Question Solution](https://leetcode.com/problems/reorder-list/solution/) | 💬 [Question Discussion](https://leetcode.com/problems/reorder-list/discuss/?orderBy=most_votes)

# %% [markdown]
# #### Test Case(s):
#
# 1. `[1,2,3,4]`
# 2. `[1,2,3,4,5]`

# %% [markdown]
# ---
# What's your idea?
#
# two iteration, first push to stack, second link together
#
# ---

# %%
from typing import Optional

# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

# %%
class Solution:
    def reorderList(self, head: Optional[ListNode]) -> None:
        """
        Do not return anything, modify head in-place instead.
        """
        if not head:
            return
            
        stack = []
        n = head
        l = 0
        while n:
            stack.append(n)
            n = n.next
            l += 1

        p = ListNode()
        dummy = p
        h = head
        for _ in range(l//2):
            p.next = h
            h = h.next
            p = p.next
            p.next = stack.pop()
            p = p.next

        if l % 2:
            p.next = h
            p = p.next
        p.next = None

        head.next = dummy.next.next

# %%
import sys, os; sys.path.append(os.path.abspath('..'))
from helper import array_to_list, print_list

l = array_to_list([1,2,3,4])
s = Solution()
s.reorderList(l)
print_list(l)
# Out:
# [1, 4, 2, 3, ]

# %%
l = array_to_list([1,2,3,4,5])
s.reorderList(l)
print_list(l)
# Out:
# [1, 5, 2, 4, 3, ]

# %% [markdown]
# 😃 Result: Accepted
# 💯 Passed Test Case: 12 / 12
# 🚀 Runtime: 0 ms, Memory: 23.5 MB
# 🉑 Runtime Percentile: better than 100.00%, Memory Percentile: better than 11.69%
# 📆 Finished At: Thu, 13 Nov 2025 14:49:12 GMT

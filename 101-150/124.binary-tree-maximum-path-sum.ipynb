# %% [markdown]
# ### 124. Binary Tree Maximum Path Sum

# %% [markdown]
# <p>A <strong>path</strong> in a binary tree is a sequence of nodes where each pair of adjacent nodes in the sequence has an edge connecting them. A node can only appear in the sequence <strong>at most once</strong>. Note that the path does not need to pass through the root.</p>
#
# <p>The <strong>path sum</strong> of a path is the sum of the node&#39;s values in the path.</p>
#
# <p>Given the <code>root</code> of a binary tree, return <em>the maximum <strong>path sum</strong> of any <strong>non-empty</strong> path</em>.</p>
#
# <p>&nbsp;</p>
# <p><strong class="example">Example 1:</strong></p>
# <img alt="" src="https://assets.leetcode.com/uploads/2020/10/13/exx1.jpg" style="width: 322px; height: 182px;" />
# <pre>
# <strong>Input:</strong> root = [1,2,3]
# <strong>Output:</strong> 6
# <strong>Explanation:</strong> The optimal path is 2 -&gt; 1 -&gt; 3 with a path sum of 2 + 1 + 3 = 6.
# </pre>
#
# <p><strong class="example">Example 2:</strong></p>
# <img alt="" src="https://assets.leetcode.com/uploads/2020/10/13/exx2.jpg" />
# <pre>
# <strong>Input:</strong> root = [-10,9,20,null,null,15,7]
# <strong>Output:</strong> 42
# <strong>Explanation:</strong> The optimal path is 15 -&gt; 20 -&gt; 7 with a path sum of 15 + 20 + 7 = 42.
# </pre>
#
# <p>&nbsp;</p>
# <p><strong>Constraints:</strong></p>
#
# <ul>
# 	<li>The number of nodes in the tree is in the range <code>[1, 3 * 10<sup>4</sup>]</code>.</li>
# 	<li><code>-1000 &lt;= Node.val &lt;= 1000</code></li>
# </ul>

# %% [markdown]
# #### Difficulty: Hard, AC rate: 41.7%
#
# #### Topics:
# Dynamic Programming | Tree | Depth-First Search | Binary Tree
#
# #### Links:
#  🎁 [Question Detail](https://leetcode.com/problems/binary-tree-maximum-path-sum/description/) | 🎉 [Question Solution](https://leetcode.com/problems/binary-tree-maximum-path-sum/solution/) | 💬 [Question Discussion](https://leetcode.com/problems/binary-tree-maximum-path-sum/discuss/?orderBy=most_votes)

# %% [markdown]
# #### Test Case(s):
#
# 1. `[1,2,3]`
# 2. `[-10,9,20,null,null,15,7]`

# %% [markdown]
# ---
# What's your idea?
#
# DP, each node tracks four paths:
#
# - only current node itself
# - ends with current node, downside its left child
# - ends with current node, downside its right child
# - involve current node and its left & right child
#
# track in a DFS way
#
# ---

# %%
from typing import Optional

# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

# %%
class Solution:
    def maxPathSum(self, root: Optional[TreeNode]) -> int:
        if not root:
            return 0
            
        self.dp = {} # (self, L, R, L&R)
        self.dfs(root)
        return max((max(v) for v in self.dp.values()))

    def dfs(self, node: Optional[TreeNode]) -> None:
        if not node:
            return
        self.dfs(node.left)
        self.dfs(node.right)
        left_node, right_node = id(node.left), id(node.right)
        (left_self, left_l, left_r, _), (right_self, right_l, right_r, _) = self.dp.get(left_node) or (0,0,0,0), self.dp.get(right_node) or (0,0,0,0)
        node_left_max = max(left_self, left_l, left_r) + node.val
        node_right_max = max(right_self, right_l, right_r) + node.val
        node_lar_max = node_left_max + node_right_max - node.val
        self.dp[id(node)] = (node.val, node_left_max, node_right_max, node_lar_max)

# %%
from helper import array_to_binary_tree

s = Solution()
s.maxPathSum(array_to_binary_tree([1,2,3]))
# Out:
# 6

# %%
s.maxPathSum(array_to_binary_tree([-10,9,20,None,None,15,7]))
# Out:
# 42

# %%
s.maxPathSum(array_to_binary_tree([-3]))
# Out:
# -3

# %%
s.maxPathSum(array_to_binary_tree([2,-1,-2]))
# Out:
# 2

# %%
s.maxPathSum(array_to_binary_tree([9,6,-3,None,None,-6,2,None,None,2,None,-6,-6,-6]))
# Out:
# 16

# %% [markdown]
# 😃 Result: Accepted
# 💯 Passed Test Case: 96 / 96
# 🚀 Runtime: 39 ms, Memory: 26.8 MB
# 🉑 Runtime Percentile: better than 5.59%, Memory Percentile: better than 12.80%
# 📆 Finished At: Tue, 18 Nov 2025 02:29:17 GMT

# %% [markdown]
# ### 39. Combination Sum

# %% [markdown]
# <p>Given an array of <strong>distinct</strong> integers <code>candidates</code> and a target integer <code>target</code>, return <em>a list of all <strong>unique combinations</strong> of </em><code>candidates</code><em> where the chosen numbers sum to </em><code>target</code><em>.</em> You may return the combinations in <strong>any order</strong>.</p>
#
# <p>The <strong>same</strong> number may be chosen from <code>candidates</code> an <strong>unlimited number of times</strong>. Two combinations are unique if the <span data-keyword="frequency-array">frequency</span> of at least one of the chosen numbers is different.</p>
#
# <p>The test cases are generated such that the number of unique combinations that sum up to <code>target</code> is less than <code>150</code> combinations for the given input.</p>
#
# <p>&nbsp;</p>
# <p><strong class="example">Example 1:</strong></p>
#
# <pre>
# <strong>Input:</strong> candidates = [2,3,6,7], target = 7
# <strong>Output:</strong> [[2,2,3],[7]]
# <strong>Explanation:</strong>
# 2 and 3 are candidates, and 2 + 2 + 3 = 7. Note that 2 can be used multiple times.
# 7 is a candidate, and 7 = 7.
# These are the only two combinations.
# </pre>
#
# <p><strong class="example">Example 2:</strong></p>
#
# <pre>
# <strong>Input:</strong> candidates = [2,3,5], target = 8
# <strong>Output:</strong> [[2,2,2,2],[2,3,3],[3,5]]
# </pre>
#
# <p><strong class="example">Example 3:</strong></p>
#
# <pre>
# <strong>Input:</strong> candidates = [2], target = 1
# <strong>Output:</strong> []
# </pre>
#
# <p>&nbsp;</p>
# <p><strong>Constraints:</strong></p>
#
# <ul>
# 	<li><code>1 &lt;= candidates.length &lt;= 30</code></li>
# 	<li><code>2 &lt;= candidates[i] &lt;= 40</code></li>
# 	<li>All elements of <code>candidates</code> are <strong>distinct</strong>.</li>
# 	<li><code>1 &lt;= target &lt;= 40</code></li>
# </ul>

# %% [markdown]
# #### Difficulty: Medium, AC rate: 75.6%
#
# #### Topics:
# Array | Backtracking
#
# #### Links:
#  🎁 [Question Detail](https://leetcode.com/problems/combination-sum/description/) | 🎉 [Question Solution](https://leetcode.com/problems/combination-sum/solution/) | 💬 [Question Discussion](https://leetcode.com/problems/combination-sum/discuss/?orderBy=most_votes)

# %% [markdown]
# #### Test Case(s):
#
# 1. `[2,3,6,7]`
# `7`
# 2. `[2,3,5]`
# `8`
# 3. `[2]`
# `1`

# %% [markdown]
# ---
# What's your idea?
#
# backtracking, sub-problem is recursive.
#
# sort candidates first, record candidates start index and remaining, then recur
#
# ---

# %%
from typing import List

# %%
from functools import reduce

class Solution:
    def combinationSum(self, candidates: List[int], target: int) -> List[List[int]]:
        candidates.sort()
        num_candiates = len(candidates)
        results = []
        stack = [[0, target]] # start index, remaining
        while stack:
            idx, remain = stack[-1]
            remain -= candidates[idx]
            if remain > 0:
                stack.append([idx, remain])
            else:
                if remain == 0:
                    comb = [stack[i-1][1] - stack[i][1] for i in range(1, len(stack))] + [candidates[idx]]
                    results.append(comb)
                stack.pop()
                
                while stack and stack[-1][0]+1 >= num_candiates:
                    stack.pop()
                else:
                    if stack:
                        stack[-1][0] += 1

        return results

# %%
s = Solution()
s.combinationSum([2,3,6,7], 7)
# Out:
# [[2, 2, 3], [7]]

# %%
s.combinationSum([2,3,5], 8)
# Out:
# [[2, 2, 2, 2], [2, 3, 3], [3, 5]]

# %%
s.combinationSum([2], 1)
# Out:
# []

# %%
s.combinationSum([7,3], 17)
# Out:
# [[3, 7, 7]]

# %% [markdown]
# 😃 Result: Accepted
# 💯 Passed Test Case: 160 / 160
# 🚀 Runtime: 4 ms, Memory: 18 MB
# 🉑 Runtime Percentile: better than 89.18%, Memory Percentile: better than 18.66%
# 📆 Finished At: Fri, 28 Nov 2025 21:40:43 GMT

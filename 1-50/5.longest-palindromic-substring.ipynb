# %% [markdown]
# ### 5. Longest Palindromic Substring

# %% [markdown]
# <p>Given a string <code>s</code>, return <em>the longest</em> <span data-keyword="palindromic-string"><em>palindromic</em></span> <span data-keyword="substring-nonempty"><em>substring</em></span> in <code>s</code>.</p>
#
# <p>&nbsp;</p>
# <p><strong class="example">Example 1:</strong></p>
#
# <pre>
# <strong>Input:</strong> s = &quot;babad&quot;
# <strong>Output:</strong> &quot;bab&quot;
# <strong>Explanation:</strong> &quot;aba&quot; is also a valid answer.
# </pre>
#
# <p><strong class="example">Example 2:</strong></p>
#
# <pre>
# <strong>Input:</strong> s = &quot;cbbd&quot;
# <strong>Output:</strong> &quot;bb&quot;
# </pre>
#
# <p>&nbsp;</p>
# <p><strong>Constraints:</strong></p>
#
# <ul>
# 	<li><code>1 &lt;= s.length &lt;= 1000</code></li>
# 	<li><code>s</code> consist of only digits and English letters.</li>
# </ul>

# %% [markdown]
# #### Difficulty: Medium, AC rate: 36.8%
#
# #### Topics:
# Two Pointers | String | Dynamic Programming
#
# #### Links:
#  🎁 [Question Detail](https://leetcode.com/problems/longest-palindromic-substring/description/) | 🎉 [Question Solution](https://leetcode.com/problems/longest-palindromic-substring/solution/) | 💬 [Question Discussion](https://leetcode.com/problems/longest-palindromic-substring/discuss/?orderBy=most_votes)
#
# #### Hints:
# <details><summary>Hint 0  🔍</summary>How can we reuse a previously computed palindrome to compute a larger palindrome?</details>
# <details><summary>Hint 1  🔍</summary>If “aba” is a palindrome, is “xabax” a palindrome? Similarly is “xabay” a palindrome?</details>
# <details><summary>Hint 2  🔍</summary>Complexity based hint:</br>
# If we use brute-force and check whether for every start and end position a substring is a palindrome we have O(n^2) start - end pairs and O(n) palindromic checks. Can we reduce the time for palindromic checks to O(1) by reusing some previous computation.</details>

# %% [markdown]
# #### Test Case(s):
#
# 1. `"babad"`
# 2. `"cbbd"`

# %% [markdown]
# ---
# What's your idea?
#
# DP, as hints show, consider `s[i+1,j-1], s[i,j-1], s[i+1,j]`
#
# ---

# %%
class Solution:
    def longestPalindrome(self, s: str) -> str:
        self.memory = {}
        self.dp(s, 0, len(s))
        max_seg_i, max_seg_j = max((k for k, v in self.memory.items() if v), key=lambda k: k[1]-k[0])
        return s[max_seg_i: max_seg_j]

    def dp(self, s, i, j):
        if i+1 > j:
            return False
        if (i,j) in self.memory:
            return self.memory[(i,j)]
        if i+1 == j:
            self.memory[(i,j)] = s[i]
            return s[i]

        if s[i] == s[j-1]:
            s_mid = self.dp(s, i+1, j-1)
            if s_mid:
                self.memory[(i,j)] = s_mid if s[i] == s_mid else True
                return self.memory[(i,j)]
            
        if s[j-1] == self.dp(s, i, j-1):
            self.memory[(i,j)] = s[j-1]
            return self.memory[(i,j)]
        if s[i] == self.dp(s, i+1, j):
            self.memory[(i,j)] = s[i]
            return self.memory[(i,j)]

        self.memory[(i,j)] = False
        return False

# %%
s = Solution()
s.longestPalindrome("babad")
# Out:
# 'bab'

# %%
s.longestPalindrome("cbbd")
# Out:
# 'bb'

# %%
s.longestPalindrome('a')
# Out:
# 'a'

# %% [markdown]
# 😃 Result: Accepted
# 💯 Passed Test Case: 143 / 143
# 🚀 Runtime: 9155 ms, Memory: 99.1 MB
# 🉑 Runtime Percentile: better than 5.00%, Memory Percentile: better than 5.88%
# 📆 Finished At: Wed, 03 Dec 2025 21:13:34 GMT

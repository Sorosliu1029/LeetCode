# %% [markdown]
# ### 191. Number of 1 Bits

# %% [markdown]
# <p>Given a positive integer <code>n</code>, write a function that returns the number of <span data-keyword="set-bit">set bits</span> in its binary representation (also known as the <a href="http://en.wikipedia.org/wiki/Hamming_weight" target="_blank">Hamming weight</a>).</p>
#
# <p>&nbsp;</p>
# <p><strong class="example">Example 1:</strong></p>
#
# <div class="example-block">
# <p><strong>Input:</strong> <span class="example-io">n = 11</span></p>
#
# <p><strong>Output:</strong> <span class="example-io">3</span></p>
#
# <p><strong>Explanation:</strong></p>
#
# <p>The input binary string <strong>1011</strong> has a total of three set bits.</p>
# </div>
#
# <p><strong class="example">Example 2:</strong></p>
#
# <div class="example-block">
# <p><strong>Input:</strong> <span class="example-io">n = 128</span></p>
#
# <p><strong>Output:</strong> <span class="example-io">1</span></p>
#
# <p><strong>Explanation:</strong></p>
#
# <p>The input binary string <strong>10000000</strong> has a total of one set bit.</p>
# </div>
#
# <p><strong class="example">Example 3:</strong></p>
#
# <div class="example-block">
# <p><strong>Input:</strong> <span class="example-io">n = 2147483645</span></p>
#
# <p><strong>Output:</strong> <span class="example-io">30</span></p>
#
# <p><strong>Explanation:</strong></p>
#
# <p>The input binary string <strong>1111111111111111111111111111101</strong> has a total of thirty set bits.</p>
# </div>
#
# <p>&nbsp;</p>
# <p><strong>Constraints:</strong></p>
#
# <ul>
# 	<li><code>1 &lt;= n &lt;= 2<sup>31</sup> - 1</code></li>
# </ul>
#
# <p>&nbsp;</p>
# <strong>Follow up:</strong> If this function is called many times, how would you optimize it?

# %% [markdown]
# #### Difficulty: Easy, AC rate: 75.6%
#
# #### Topics:
# Divide and Conquer | Bit Manipulation
#
# #### Links:
#  🎁 [Question Detail](https://leetcode.com/problems/number-of-1-bits/description/) | 🎉 [Question Solution](https://leetcode.com/problems/number-of-1-bits/solution/) | 💬 [Question Discussion](https://leetcode.com/problems/number-of-1-bits/discuss/?orderBy=most_votes)

# %% [markdown]
# #### Test Case(s):
#
# 1. `11`
# 2. `128`
# 3. `2147483645`

# %% [markdown]
# ---
# What's your idea?
#
# bit shift
#
# ---

# %%
class Solution:
    hex_map = { 0:0, 1:1, 2:1, 3:2, 4:1, 5:2, 6:2, 7:3,
                8:1, 9:2, 10:2, 11:3, 12:2, 13:3, 14:3, 15:4 }
    
    def hammingWeight(self, n: int) -> int:
        c = 0
        while n:
            c += self.hex_map[n%16]
            n >>= 4
        return c

# %%
s = Solution()
s.hammingWeight(11)
# Out:
# 3

# %%
s.hammingWeight(128)
# Out:
# 1

# %%
s.hammingWeight(2147483645)
# Out:
# 30

# %% [markdown]
# 😃 Result: Accepted
# 💯 Passed Test Case: 598 / 598
# 🚀 Runtime: 0 ms, Memory: 17.8 MB
# 🉑 Runtime Percentile: better than 100.00%, Memory Percentile: better than 31.13%
# 📆 Finished At: Wed, 12 Nov 2025 20:12:40 GMT

# %% [markdown]
# ### 198. House Robber

# %% [markdown]
# <p>You are a professional robber planning to rob houses along a street. Each house has a certain amount of money stashed, the only constraint stopping you from robbing each of them is that adjacent houses have security systems connected and <b>it will automatically contact the police if two adjacent houses were broken into on the same night</b>.</p>
#
# <p>Given an integer array <code>nums</code> representing the amount of money of each house, return <em>the maximum amount of money you can rob tonight <b>without alerting the police</b></em>.</p>
#
# <p>&nbsp;</p>
# <p><strong class="example">Example 1:</strong></p>
#
# <pre>
# <strong>Input:</strong> nums = [1,2,3,1]
# <strong>Output:</strong> 4
# <strong>Explanation:</strong> Rob house 1 (money = 1) and then rob house 3 (money = 3).
# Total amount you can rob = 1 + 3 = 4.
# </pre>
#
# <p><strong class="example">Example 2:</strong></p>
#
# <pre>
# <strong>Input:</strong> nums = [2,7,9,3,1]
# <strong>Output:</strong> 12
# <strong>Explanation:</strong> Rob house 1 (money = 2), rob house 3 (money = 9) and rob house 5 (money = 1).
# Total amount you can rob = 2 + 9 + 1 = 12.
# </pre>
#
# <p>&nbsp;</p>
# <p><strong>Constraints:</strong></p>
#
# <ul>
# 	<li><code>1 &lt;= nums.length &lt;= 100</code></li>
# 	<li><code>0 &lt;= nums[i] &lt;= 400</code></li>
# </ul>

# %% [markdown]
# #### Difficulty: Medium, AC rate: 52.7%
#
# #### Topics:
# Array | Dynamic Programming
#
# #### Links:
#  🎁 [Question Detail](https://leetcode.com/problems/house-robber/description/) | 🎉 [Question Solution](https://leetcode.com/problems/house-robber/solution/) | 💬 [Question Discussion](https://leetcode.com/problems/house-robber/discuss/?orderBy=most_votes)

# %% [markdown]
# #### Test Case(s):
#
# 1. `[1,2,3,1]`
# 2. `[2,7,9,3,1]`

# %% [markdown]
# ---
# What's your idea?
#
# DP, each tracks max robbery within range(i, j), build from smallest range, then dynamically build bigger range with left range and right range
#
# ---

# %%
from typing import List

# %%
class Solution:
    def rob(self, nums: List[int]) -> int:
        n = len(nums)
        segs = {(i,i+1): nums[i] for i in range(n)}
        for w in range(1, n+1):
            for i in range(n-w+1):
                j = i + w
                segs[(i,i+w)] = max((segs.get((i,k-1), 0) + nums[k] + segs.get((k+2,j), 0) for k in range(i, j)))
        return segs[(0, n)]

# %%
s = Solution()
s.rob([1,2,3,1])
# Out:
# 4

# %%
s.rob([2,7,9,3,1])
# Out:
# 12

# %% [markdown]
# 😃 Result: Accepted
# 💯 Passed Test Case: 70 / 70
# 🚀 Runtime: 207 ms, Memory: 18.3 MB
# 🉑 Runtime Percentile: better than 1.13%, Memory Percentile: better than 12.42%
# 📆 Finished At: Tue, 18 Nov 2025 04:17:23 GMT

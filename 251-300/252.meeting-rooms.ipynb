# %% [markdown]
# ### 252. Meeting Rooms

# %% [markdown]
# <p>Given an array of meeting time <code>intervals</code>&nbsp;where <code>intervals[i] = [start<sub>i</sub>, end<sub>i</sub>]</code>, determine if a person could attend all meetings.</p>
#
# <p>&nbsp;</p>
# <p><strong class="example">Example 1:</strong></p>
# <pre><strong>Input:</strong> intervals = [[0,30],[5,10],[15,20]]
# <strong>Output:</strong> false
# </pre><p><strong class="example">Example 2:</strong></p>
# <pre><strong>Input:</strong> intervals = [[7,10],[2,4]]
# <strong>Output:</strong> true
# </pre>
# <p>&nbsp;</p>
# <p><strong>Constraints:</strong></p>
#
# <ul>
# 	<li><code>0 &lt;= intervals.length &lt;= 10<sup>4</sup></code></li>
# 	<li><code>intervals[i].length == 2</code></li>
# 	<li><code>0 &lt;= start<sub>i</sub> &lt;&nbsp;end<sub>i</sub> &lt;= 10<sup>6</sup></code></li>
# </ul>

# %% [markdown]
# #### Difficulty: Easy, AC rate: 59.2%
#
# #### Topics:
# Array | Sorting
#
# #### Links:
#  🎁 [Question Detail](https://leetcode.com/problems/meeting-rooms/description/) | 🎉 [Question Solution](https://leetcode.com/problems/meeting-rooms/solution/) | 💬 [Question Discussion](https://leetcode.com/problems/meeting-rooms/discuss/?orderBy=most_votes)

# %% [markdown]
# #### Test Case(s):
#
# 1. `[[0,30],[5,10],[15,20]]`
# 2. `[[7,10],[2,4]]`

# %% [markdown]
# ---
# What's your idea?
#
# naive, sort by start time, then simulate
#
# ---

# %%
from typing import List

# %%
class Solution:
    def canAttendMeetings(self, intervals: List[List[int]]) -> bool:
        intervals = sorted(intervals, key=lambda i: i[0])
        end = -1
        for s, e in intervals:
            if s < end:
                return False
            end = e
        return True

# %%
s = Solution()
s.canAttendMeetings([[0,30],[5,10],[15,20]])
# Out:
# False

# %%
s.canAttendMeetings([[7,10],[2,4]])
# Out:
# True

# %% [markdown]
# 😃 Result: Accepted
# 💯 Passed Test Case: 79 / 79
# 🚀 Runtime: 1 ms, Memory: 20 MB
# 🉑 Runtime Percentile: better than 85.32%, Memory Percentile: better than 16.52%
# 📆 Finished At: Thu, 20 Nov 2025 14:56:10 GMT

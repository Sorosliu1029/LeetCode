# %% [markdown]
# ### 261. Graph Valid Tree

# %% [markdown]
# <p>You have a graph of <code>n</code> nodes labeled from <code>0</code> to <code>n - 1</code>. You are given an integer n and a list of <code>edges</code> where <code>edges[i] = [a<sub>i</sub>, b<sub>i</sub>]</code> indicates that there is an undirected edge between nodes <code>a<sub>i</sub></code> and <code>b<sub>i</sub></code> in the graph.</p>
#
# <p>Return <code>true</code> <em>if the edges of the given graph make up a valid tree, and</em> <code>false</code> <em>otherwise</em>.</p>
#
# <p>&nbsp;</p>
# <p><strong class="example">Example 1:</strong></p>
# <img alt="" src="https://assets.leetcode.com/uploads/2021/03/12/tree1-graph.jpg" style="width: 222px; height: 302px;" />
# <pre>
# <strong>Input:</strong> n = 5, edges = [[0,1],[0,2],[0,3],[1,4]]
# <strong>Output:</strong> true
# </pre>
#
# <p><strong class="example">Example 2:</strong></p>
# <img alt="" src="https://assets.leetcode.com/uploads/2021/03/12/tree2-graph.jpg" style="width: 382px; height: 222px;" />
# <pre>
# <strong>Input:</strong> n = 5, edges = [[0,1],[1,2],[2,3],[1,3],[1,4]]
# <strong>Output:</strong> false
# </pre>
#
# <p>&nbsp;</p>
# <p><strong>Constraints:</strong></p>
#
# <ul>
# 	<li><code>1 &lt;= n &lt;= 2000</code></li>
# 	<li><code>0 &lt;= edges.length &lt;= 5000</code></li>
# 	<li><code>edges[i].length == 2</code></li>
# 	<li><code>0 &lt;= a<sub>i</sub>, b<sub>i</sub> &lt; n</code></li>
# 	<li><code>a<sub>i</sub> != b<sub>i</sub></code></li>
# 	<li>There are no self-loops or repeated edges.</li>
# </ul>

# %% [markdown]
# #### Difficulty: Medium, AC rate: 49.6%
#
# #### Topics:
# Depth-First Search | Breadth-First Search | Union Find | Graph
#
# #### Links:
#  🎁 [Question Detail](https://leetcode.com/problems/graph-valid-tree/description/) | 🎉 [Question Solution](https://leetcode.com/problems/graph-valid-tree/solution/) | 💬 [Question Discussion](https://leetcode.com/problems/graph-valid-tree/discuss/?orderBy=most_votes)
#
# #### Hints:
# <details><summary>Hint 0  🔍</summary>Given <code>n = 5</code> and <code>edges = [[0, 1], [1, 2], [3, 4]]</code>, what should your return? Is this case a valid tree?</details>
# <details><summary>Hint 1  🔍</summary>According to the <a href="https://en.wikipedia.org/wiki/Tree_(graph_theory)" target="_blank">definition of tree on Wikipedia</a>: “a tree is an undirected graph in which any two vertices are connected by <i>exactly</i> one path. In other words, any connected graph without simple cycles is a tree.”</details>

# %% [markdown]
# #### Test Case(s):
#
# 1. `5`
# `[[0,1],[0,2],[0,3],[1,4]]`
# 2. `5`
# `[[0,1],[1,2],[2,3],[1,3],[1,4]]`

# %% [markdown]
# ---
# What's your idea?
#
# same as 323, union find, early return if detect a cycle
#
# ---

# %%
from typing import List

# %%
class Solution:
    def validTree(self, n: int, edges: List[List[int]]) -> bool:
        sets = [set([i]) for i in range(n)]
        belongs = list(range(n))
        for (n1, n2) in edges:
            b1, b2 = belongs[n1], belongs[n2]
            if b1 == b2:
                return False
            set1, set2 = sets[b1], sets[b2]
            if len(set1) > len(set2):
                set1, set2 = set2, set1
                n1, n2 = n2, n1
            for n in set1:
                belongs[n] = belongs[n2]
            set2.update(set1)
        return len(set(belongs)) == 1

# %%
s = Solution()
s.validTree(5, [[0,1],[0,2],[0,3],[1,4]])
# Out:
# True

# %%
s.validTree(5, [[0,1],[1,2],[2,3],[1,3],[1,4]])
# Out:
# False

# %% [markdown]
# 😃 Result: Accepted
# 💯 Passed Test Case: 47 / 47
# 🚀 Runtime: 3 ms, Memory: 19.3 MB
# 🉑 Runtime Percentile: better than 47.83%, Memory Percentile: better than 32.28%
# 📆 Finished At: Tue, 18 Nov 2025 16:29:54 GMT

# %% [markdown]
# ### 704. Binary Search

# %% [markdown]
# <p>Given an array of integers <code>nums</code> which is sorted in ascending order, and an integer <code>target</code>, write a function to search <code>target</code> in <code>nums</code>. If <code>target</code> exists, then return its index. Otherwise, return <code>-1</code>.</p>
#
# <p>You must write an algorithm with <code>O(log n)</code> runtime complexity.</p>
#
# <p>&nbsp;</p>
# <p><strong class="example">Example 1:</strong></p>
#
# <pre>
# <strong>Input:</strong> nums = [-1,0,3,5,9,12], target = 9
# <strong>Output:</strong> 4
# <strong>Explanation:</strong> 9 exists in nums and its index is 4
# </pre>
#
# <p><strong class="example">Example 2:</strong></p>
#
# <pre>
# <strong>Input:</strong> nums = [-1,0,3,5,9,12], target = 2
# <strong>Output:</strong> -1
# <strong>Explanation:</strong> 2 does not exist in nums so return -1
# </pre>
#
# <p>&nbsp;</p>
# <p><strong>Constraints:</strong></p>
#
# <ul>
# 	<li><code>1 &lt;= nums.length &lt;= 10<sup>4</sup></code></li>
# 	<li><code>-10<sup>4</sup> &lt; nums[i], target &lt; 10<sup>4</sup></code></li>
# 	<li>All the integers in <code>nums</code> are <strong>unique</strong>.</li>
# 	<li><code>nums</code> is sorted in ascending order.</li>
# </ul>

# %% [markdown]
# #### Difficulty: Easy, AC rate: 60.2%
#
# #### Topics:
# Array | Binary Search
#
# #### Links:
#  🎁 [Question Detail](https://leetcode.com/problems/binary-search/description/) | 🎉 [Question Solution](https://leetcode.com/problems/binary-search/solution/) | 💬 [Question Discussion](https://leetcode.com/problems/binary-search/discuss/?orderBy=most_votes)

# %% [markdown]
# #### Test Case(s):
#
# 1. `[-1,0,3,5,9,12]`
# `9`
# 2. `[-1,0,3,5,9,12]`
# `2`

# %% [markdown]
# ---
# What's your idea?
#
# standard binary search
#
# ---

# %%
from typing import List

# %%
class Solution:
    def search(self, nums: List[int], target: int) -> int:
        l, r = 0, len(nums)
        while l < r-1:
            m = (l+r)//2
            if nums[m] > target:
                r = m
            elif nums[m] < target:
                l = m
            else:
                return m

        return 0 if nums[0] == target else -1

# %%
s = Solution()
s.search([-1,0,3,5,9,12], 9)
# Out:
# 4

# %%
s.search([-1,0,3,5,9,12], 2)
# Out:
# -1

# %%
s.search([5], 5)
# Out:
# 0

# %%
s.search([2,5], 5)
# Out:
# 1

# %% [markdown]
# 😃 Result: Accepted
# 💯 Passed Test Case: 47 / 47
# 🚀 Runtime: 0 ms, Memory: 18.7 MB
# 🉑 Runtime Percentile: better than 100.00%, Memory Percentile: better than 72.77%
# 📆 Finished At: Fri, 28 Nov 2025 04:30:33 GMT

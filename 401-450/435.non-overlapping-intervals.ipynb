# %% [markdown]
# ### 435. Non-overlapping Intervals

# %% [markdown]
# <p>Given an array of intervals <code>intervals</code> where <code>intervals[i] = [start<sub>i</sub>, end<sub>i</sub>]</code>, return <em>the minimum number of intervals you need to remove to make the rest of the intervals non-overlapping</em>.</p>
#
# <p><strong>Note</strong> that intervals which only touch at a point are <strong>non-overlapping</strong>. For example, <code>[1, 2]</code> and <code>[2, 3]</code> are non-overlapping.</p>
#
# <p>&nbsp;</p>
# <p><strong class="example">Example 1:</strong></p>
#
# <pre>
# <strong>Input:</strong> intervals = [[1,2],[2,3],[3,4],[1,3]]
# <strong>Output:</strong> 1
# <strong>Explanation:</strong> [1,3] can be removed and the rest of the intervals are non-overlapping.
# </pre>
#
# <p><strong class="example">Example 2:</strong></p>
#
# <pre>
# <strong>Input:</strong> intervals = [[1,2],[1,2],[1,2]]
# <strong>Output:</strong> 2
# <strong>Explanation:</strong> You need to remove two [1,2] to make the rest of the intervals non-overlapping.
# </pre>
#
# <p><strong class="example">Example 3:</strong></p>
#
# <pre>
# <strong>Input:</strong> intervals = [[1,2],[2,3]]
# <strong>Output:</strong> 0
# <strong>Explanation:</strong> You don&#39;t need to remove any of the intervals since they&#39;re already non-overlapping.
# </pre>
#
# <p>&nbsp;</p>
# <p><strong>Constraints:</strong></p>
#
# <ul>
# 	<li><code>1 &lt;= intervals.length &lt;= 10<sup>5</sup></code></li>
# 	<li><code>intervals[i].length == 2</code></li>
# 	<li><code>-5 * 10<sup>4</sup> &lt;= start<sub>i</sub> &lt; end<sub>i</sub> &lt;= 5 * 10<sup>4</sup></code></li>
# </ul>

# %% [markdown]
# #### Difficulty: Medium, AC rate: 56.3%
#
# #### Topics:
# Array | Dynamic Programming | Greedy | Sorting
#
# #### Links:
#  🎁 [Question Detail](https://leetcode.com/problems/non-overlapping-intervals/description/) | 🎉 [Question Solution](https://leetcode.com/problems/non-overlapping-intervals/solution/) | 💬 [Question Discussion](https://leetcode.com/problems/non-overlapping-intervals/discuss/?orderBy=most_votes)

# %% [markdown]
# #### Test Case(s):
#
# 1. `[[1,2],[2,3],[3,4],[1,3]]`
# 2. `[[1,2],[1,2],[1,2]]`
# 3. `[[1,2],[2,3]]`

# %% [markdown]
# ---
# What's your idea?
#
# ---

# %%
from typing import List

# %%
class Solution:
    def eraseOverlapIntervals(self, intervals: List[List[int]]) -> int:
        intervals = sorted(intervals)
        print(intervals)
        dp = [1] # max number of intervals that reach to intervals[i]
        frontiers = [0]
        for i in range(1, len(intervals)):
            s, e = intervals[i]
            chosen, update_frontier_idx, max_num_intervals = None, None, 0
            for j, interval_idx in enumerate(frontiers):
                if s >= intervals[interval_idx][1] and dp[interval_idx] + 1 > max_num_intervals:
                    max_num_intervals = dp[interval_idx] + 1
                    chosen = i
                    update_frontier_idx = j
            if update_frontier_idx is not None:
                frontiers[update_frontier_idx] = chosen
                dp.append(max_num_intervals)
            else:
                frontiers.append(i)
                dp.append(dp[frontiers[0]])
            print([intervals[f] for f in frontiers], dp)
                
        return len(intervals) - max(dp)

# %%
s = Solution()
s.eraseOverlapIntervals([[1,2],[2,3],[3,4],[1,3]])
# Out:
# [[1, 2], [1, 3], [2, 3], [3, 4]]
# [[1, 2], [1, 3]] [1, 1]
# [[2, 3], [1, 3]] [1, 1, 2]
# [[3, 4], [1, 3]] [1, 1, 2, 3]
# 1

# %%
s.eraseOverlapIntervals([[1,2],[1,2],[1,2]])
# Out:
# 2

# %%
s.eraseOverlapIntervals([[1,2],[2,3]])
# Out:
# 0

# %%
s.eraseOverlapIntervals([[-52,31],[-73,-26],[82,97],[-65,-11],[-62,-49],[95,99],[58,95],[-31,49],[66,98],[-63,2],[30,47],[-40,-26]])
# Out:
# 7

# %%
s.eraseOverlapIntervals([[-3035,30075],[1937,6906],[11834,20971],[44578,45600],[28565,37578],[19621,34415],[32985,36313],[-8144,1080],[-15279,21851],[-27140,-14703],[-12098,16264],[-36057,-16287],[47939,48626],[-15129,-5773],[10508,46685],[-35323,-26257]])
# Out:
# [[-36057, -16287], [-35323, -26257], [-27140, -14703], [-15279, 21851], [-15129, -5773], [-12098, 16264], [-8144, 1080], [-3035, 30075], [1937, 6906], [10508, 46685], [11834, 20971], [19621, 34415], [28565, 37578], [32985, 36313], [44578, 45600], [47939, 48626]]
# [[-36057, -16287], [-35323, -26257]] [1, 1]
# [[-36057, -16287], [-35323, -26257], [-27140, -14703]] [1, 1, 1]
# [[-15279, 21851], [-35323, -26257], [-27140, -14703]] [1, 1, 1, 2]
# [[-15279, 21851], [-15129, -5773], [-27140, -14703]] [1, 1, 1, 2, 2]
# [[-15279, 21851], [-15129, -5773], [-12098, 16264]] [1, 1, 1, 2, 2, 2]
# [[-15279, 21851], [-15129, -5773], [-12098, 16264], [-8144, 1080]] [1, 1, 1, 2, 2, 2, 2]
# [[-15279, 21851], [-3035, 30075], [-12098, 16264], [-8144, 1080]] [1, 1, 1, 2, 2, 2, 2, 3]
# [[-15279, 21851], [-3035, 30075], [-12098, 16264], [1937, 6906]] [1, 1, 1, 2, 2, 2, 2, 3, 3]
# [[-15279, 21851], [-3035, 30075], [-12098, 16264], [10508, 46685]] [1, 1, 1, 2, 2, 2, 2, 3, 3, 4]
# ...

# %% [markdown]
# 🐛 Result: Wrong Answer
# 📥 Input: `[[-3035,30075],[1937,6906],[11834,20971],[44578,45600],[28565,37578],[19621,34415],[32985,36313],[-8144,1080],[-15279,21851],[-27140,-14703],[-12098,16264],[-36057,-16287],[47939,48626],[-15129,-5773],[10508,46685],[-35323,-26257]]`
# 📤 Output: `10`
# ✅ Expected: `9`
# 💯 Passed Test Case: 18 / 59
